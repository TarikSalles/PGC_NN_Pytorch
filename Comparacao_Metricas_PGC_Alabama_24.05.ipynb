# %% [markdown]
# <h1> <b> Visualização e Comparação dos Resultados do PGC-NN Pytorch e Tensorflow no Dataset Alabama. Resultados com batch_size 6 e 12, e número de épocas 20 e 40</b>
# </h1>

# %% [markdown]
# #Imports e Unzip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

# %%
# !unzip Alabama.zip

# %% [markdown]
# #Funções utilizadas

# %%
def fazer_histograma(df1,df2,descricao1,descricao2):
  plt.hist(df1, alpha=0.5, label=descricao1)
  plt.hist(df2, alpha=0.5, label=descricao2)
  plt.xlabel('Valores')
  plt.ylabel('Frequência')
  plt.title('Histograma dos Dados')
  plt.legend(loc='upper right')
  plt.show()

def comparar_graficamente(dict1, dict2, descricao1, descricao2, tipo):
    categorias = list(dict1.keys())
    valores_dict1 = list(dict1.values())
    valores_dict2 = list(dict2.values())

    posicoes = np.arange(len(categorias))

    largura_barra = 0.35

    plt.figure(figsize=(10, 6))
    plt.bar(posicoes - largura_barra/2, valores_dict1, width=largura_barra, label=descricao1, color='blue')
    plt.bar(posicoes + largura_barra/2, valores_dict2, width=largura_barra, label=descricao2, color='orange')

    plt.xlabel('Categorias')
    plt.ylabel('Valores')
    plt.title('Comparação métrica média ' + tipo + ':')
    plt.xticks(posicoes, categorias)
    plt.legend()

    plt.tight_layout()
    plt.show()


def plotar_imagens(file1, file2):
    img1 = mpimg.imread(file1)
    img2 = mpimg.imread(file2)

    fig, axs = plt.subplots(1, 2, figsize=(20, 20))

    axs[0].imshow(img1)
    axs[0].axis('off')

    axs[1].imshow(img2)
    axs[1].axis('off')


    plt.show()

# %%
def calcular_medias_por_coluna(nome_arquivo):
    df = pd.read_csv(nome_arquivo)
    df = df.astype(float)

    medias = df.mean().tolist()

    rotulos_colunas = df.columns.tolist()

    medias_com_rotulos = dict(zip(rotulos_colunas, medias))

    return medias_com_rotulos

# %%
def calcular_medias_por_coluna(nome_arquivo):
    df = pd.read_csv(nome_arquivo)
    df = df.astype(float)

    medias = df.mean().tolist()

    rotulos_colunas = df.columns.tolist()

    medias_com_rotulos = dict(zip(rotulos_colunas, medias))

    return medias_com_rotulos

# %%
def retornar_linha_valor(nome_arquivo, linha):
    df = pd.read_csv(nome_arquivo)
    df = df.astype(float)

    valores_linha = df.iloc[linha].to_dict()

    return valores_linha

# %% [markdown]
# #Número de Épocas 20, batch_size 6

# %% [markdown]
# <h1> Precisão </h1>

# %%
precisao_pytorch_media = calcular_medias_por_coluna("Alabama/Pytorch/Batch_Size_6/Epochs_20/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/precision.csv")
precisao_tensorflow_media = calcular_medias_por_coluna("/content/Alabama/Tensorflow/Batch_Size_6/20_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/precision.csv")
comparar_graficamente(precisao_pytorch_media, precisao_tensorflow_media,"pytorch","tensorflow","precision")

# %% [markdown]
# <h1> Recall </h1>

# %%
precisao_pytorch_media = calcular_medias_por_coluna("Alabama/Pytorch/Batch_Size_6/Epochs_20/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/recall.csv")
precisao_tensorflow_media = calcular_medias_por_coluna("/content/Alabama/Tensorflow/Batch_Size_6/20_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/recall.csv")
comparar_graficamente(precisao_pytorch_media, precisao_tensorflow_media,"pytorch","tensorflow","recall")

# %% [markdown]
# <h1> Fscore </h1>

# %%
precisao_pytorch_media = calcular_medias_por_coluna("Alabama/Pytorch/Batch_Size_6/Epochs_20/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fscore.csv")
precisao_tensorflow_media = calcular_medias_por_coluna("/content/Alabama/Tensorflow/Batch_Size_6/20_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fscore.csv")
comparar_graficamente(precisao_pytorch_media, precisao_tensorflow_media,"pytorch","tensorflow","fscore")

# %% [markdown]
# <h1> Por fold </h1>

# %% [markdown]
# <h1> Precisão por fold </h1>

# %%
num_linhas = pd.read_csv("/content/Alabama/Tensorflow/Batch_Size_6/20_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/precision.csv").shape[0]
for x in range(num_linhas):
  print(f"Precisao fold {x+1}:")
  print("\n\n")
  precisao_pytorch_linha_x = retornar_linha_valor("Alabama/Pytorch/Batch_Size_6/Epochs_20/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/precision.csv",x)
  precisao_tensorflow_linha_x= retornar_linha_valor("/content/Alabama/Tensorflow/Batch_Size_6/20_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/precision.csv",x)
  comparar_graficamente(precisao_pytorch_linha_x, precisao_tensorflow_linha_x,"pytorch","tensorflow","precision")
  print("\n\n")
# Out:
# Precisao fold 1:
# Precisao fold 2:
# Precisao fold 3:
# Precisao fold 4:
# Precisao fold 5:

# %% [markdown]
# <h1> Fscore por linha </h1>

# %%
for x in range(num_linhas):
  print(f"Fscore fold {x+1}:")
  print("\n\n")
  fscore_pytorch_linha_x = retornar_linha_valor("Alabama/Pytorch/Batch_Size_6/Epochs_20/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fscore.csv",x)
  fscore_tensorflow_linha_x= retornar_linha_valor("/content/Alabama/Tensorflow/Batch_Size_6/20_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fscore.csv",x)
  comparar_graficamente(fscore_pytorch_linha_x, fscore_tensorflow_linha_x,"pytorch","tensorflow","fscore")
  print("\n\n")
# Out:
# Fscore fold 1:
# Fscore fold 2:
# Fscore fold 3:
# Fscore fold 4:
# Fscore fold 5:

# %% [markdown]
# <h1> Recall por fold </h1>

# %%
for x in range(num_linhas):
  print(f"Recall fold {x+1}:")
  print("\n\n")
  recall_pytorch_linha_x = retornar_linha_valor("Alabama/Pytorch/Batch_Size_6/Epochs_20/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/recall.csv",x)
  recall_tensorflow_linha_x= retornar_linha_valor("/content/Alabama/Tensorflow/Batch_Size_6/20_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/recall.csv",x)
  comparar_graficamente(recall_pytorch_linha_x, recall_tensorflow_linha_x,"pytorch","tensorflow","recall")
  print("\n\n")
# Out:
# Recall fold 1:
# Recall fold 2:
# Recall fold 3:
# Recall fold 4:
# Recall fold 5:

# %% [markdown]
# #Número de Épocas 20, batch_size 12

# %% [markdown]
# <h1> Precisão </h1>

# %%
precisao_pytorch_media = calcular_medias_por_coluna("Alabama/Pytorch/Batch_Size_12/Epochs_20/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/precision.csv")
precisao_tensorflow_media = calcular_medias_por_coluna("/content/Alabama/Tensorflow/Batch_Size_12/20_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/precision.csv")
comparar_graficamente(precisao_pytorch_media, precisao_tensorflow_media,"pytorch","tensorflow","precision")

# %% [markdown]
# <h1> Recall </h1>

# %%
precisao_pytorch_media = calcular_medias_por_coluna("Alabama/Pytorch/Batch_Size_12/Epochs_20/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/recall.csv")
precisao_tensorflow_media = calcular_medias_por_coluna("/content/Alabama/Tensorflow/Batch_Size_12/20_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/recall.csv")
comparar_graficamente(precisao_pytorch_media, precisao_tensorflow_media,"pytorch","tensorflow","recall")

# %% [markdown]
# <h1> Fscore </h1>

# %%
precisao_pytorch_media = calcular_medias_por_coluna("Alabama/Pytorch/Batch_Size_12/Epochs_20/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fscore.csv")
precisao_tensorflow_media = calcular_medias_por_coluna("/content/Alabama/Tensorflow/Batch_Size_12/20_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fscore.csv")
comparar_graficamente(precisao_pytorch_media, precisao_tensorflow_media,"pytorch","tensorflow","fscore")

# %% [markdown]
# <h1> Por fold </h1>

# %% [markdown]
# <h1> Precisão por fold </h1>

# %%
num_linhas = pd.read_csv("/content/Alabama/Tensorflow/Batch_Size_12/20_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/precision.csv").shape[0]
for x in range(num_linhas):
  print(f"Precisao fold {x+1}:")
  print("\n\n")
  precisao_pytorch_linha_x = retornar_linha_valor("Alabama/Pytorch/Batch_Size_12/Epochs_20/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/precision.csv",x)
  precisao_tensorflow_linha_x= retornar_linha_valor("/content/Alabama/Tensorflow/Batch_Size_12/20_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/precision.csv",x)
  comparar_graficamente(precisao_pytorch_linha_x, precisao_tensorflow_linha_x,"pytorch","tensorflow","precision")
  print("\n\n")
# Out:
# Precisao fold 1:
# Precisao fold 2:
# Precisao fold 3:
# Precisao fold 4:
# Precisao fold 5:

# %% [markdown]
# <h1> Fscore por linha </h1>

# %%
for x in range(num_linhas):
  print(f"Fscore fold {x+1}:")
  print("\n\n")
  fscore_pytorch_linha_x = retornar_linha_valor("Alabama/Pytorch/Batch_Size_12/Epochs_20/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fscore.csv",x)
  fscore_tensorflow_linha_x= retornar_linha_valor("/content/Alabama/Tensorflow/Batch_Size_12/20_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fscore.csv",x)
  comparar_graficamente(fscore_pytorch_linha_x, fscore_tensorflow_linha_x,"pytorch","tensorflow","fscore")
  print("\n\n")
# Out:
# Fscore fold 1:
# Fscore fold 2:
# Fscore fold 3:
# Fscore fold 4:
# Fscore fold 5:

# %% [markdown]
# <h1> Recall por fold </h1>

# %%
for x in range(num_linhas):
  print(f"Recall fold {x+1}:")
  print("\n\n")
  recall_pytorch_linha_x = retornar_linha_valor("Alabama/Pytorch/Batch_Size_12/Epochs_20/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/recall.csv",x)
  recall_tensorflow_linha_x= retornar_linha_valor("/content/Alabama/Tensorflow/Batch_Size_12/20_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/recall.csv",x)
  comparar_graficamente(recall_pytorch_linha_x, recall_tensorflow_linha_x,"pytorch","tensorflow","recall")
  print("\n\n")
# Out:
# Recall fold 1:
# Recall fold 2:
# Recall fold 3:
# Recall fold 4:
# Recall fold 5:

# %% [markdown]
# #Número de Épocas 40, batch_size 6

# %% [markdown]
# <h1> Precisão </h1>

# %%
precisao_pytorch_media = calcular_medias_por_coluna("Alabama/Pytorch/Batch_Size_6/Epochs_40/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/precision.csv")
precisao_tensorflow_media = calcular_medias_por_coluna("/content/Alabama/Tensorflow/Batch_Size_6/40_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/precision.csv")
comparar_graficamente(precisao_pytorch_media, precisao_tensorflow_media,"pytorch","tensorflow","precision")

# %% [markdown]
# <h1> Recall </h1>

# %%
precisao_pytorch_media = calcular_medias_por_coluna("Alabama/Pytorch/Batch_Size_6/Epochs_40/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/recall.csv")
precisao_tensorflow_media = calcular_medias_por_coluna("/content/Alabama/Tensorflow/Batch_Size_6/40_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/recall.csv")
comparar_graficamente(precisao_pytorch_media, precisao_tensorflow_media,"pytorch","tensorflow","recall")

# %% [markdown]
# <h1> Fscore </h1>

# %%
precisao_pytorch_media = calcular_medias_por_coluna("Alabama/Pytorch/Batch_Size_6/Epochs_40/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fscore.csv")
precisao_tensorflow_media = calcular_medias_por_coluna("/content/Alabama/Tensorflow/Batch_Size_6/40_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fscore.csv")
comparar_graficamente(precisao_pytorch_media, precisao_tensorflow_media,"pytorch","tensorflow","fscore")

# %% [markdown]
# <h1> Por fold </h1>

# %% [markdown]
# <h1> Precisão por fold </h1>

# %%
num_linhas = pd.read_csv("/content/Alabama/Tensorflow/Batch_Size_6/40_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/precision.csv").shape[0]
for x in range(num_linhas):
  print(f"Precisao fold {x+1}:")
  print("\n\n")
  precisao_pytorch_linha_x = retornar_linha_valor("Alabama/Pytorch/Batch_Size_6/Epochs_40/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/precision.csv",x)
  precisao_tensorflow_linha_x= retornar_linha_valor("/content/Alabama/Tensorflow/Batch_Size_6/40_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/precision.csv",x)
  comparar_graficamente(precisao_pytorch_linha_x, precisao_tensorflow_linha_x,"pytorch","tensorflow","precision")
  print("\n\n")
# Out:
# Precisao fold 1:
# Precisao fold 2:
# Precisao fold 3:
# Precisao fold 4:
# Precisao fold 5:

# %% [markdown]
# <h1> Fscore por linha </h1>

# %%
for x in range(num_linhas):
  print(f"Fscore fold {x+1}:")
  print("\n\n")
  fscore_pytorch_linha_x = retornar_linha_valor("Alabama/Pytorch/Batch_Size_6/Epochs_40/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fscore.csv",x)
  fscore_tensorflow_linha_x= retornar_linha_valor("/content/Alabama/Tensorflow/Batch_Size_6/40_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fscore.csv",x)
  comparar_graficamente(fscore_pytorch_linha_x, fscore_tensorflow_linha_x,"pytorch","tensorflow","fscore")
  print("\n\n")
# Out:
# Fscore fold 1:
# Fscore fold 2:
# Fscore fold 3:
# Fscore fold 4:
# Fscore fold 5:

# %% [markdown]
# <h1> Recall por fold </h1>

# %%
for x in range(num_linhas):
  print(f"Recall fold {x+1}:")
  print("\n\n")
  recall_pytorch_linha_x = retornar_linha_valor("Alabama/Pytorch/Batch_Size_6/Epochs_40/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/recall.csv",x)
  recall_tensorflow_linha_x= retornar_linha_valor("/content/Alabama/Tensorflow/Batch_Size_6/40_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/recall.csv",x)
  comparar_graficamente(recall_pytorch_linha_x, recall_tensorflow_linha_x,"pytorch","tensorflow","recall")
  print("\n\n")
# Out:
# Recall fold 1:
# Recall fold 2:
# Recall fold 3:
# Recall fold 4:
# Recall fold 5:

# %% [markdown]
# #Comparação Loss: Epochs 20 e 40, batch_size 6

# %%
print("\n\n")
for x in range(num_linhas):
  print(f"Fold {x+1}")
  print("\n")
  print("Pytorch:")
  plotar_imagens(f"/content/Alabama/Pytorch/Batch_Size_6/Epochs_20/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fold_{x}_replication_0_history_loss.png",f"/content/Alabama/Pytorch/Batch_Size_6/Epochs_40/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fold_{x}_replication_0_history_loss.png")
  print("Tensorflow:")
  plotar_imagens(f"/content/Alabama/Tensorflow/Batch_Size_6/20_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fold_{x}_replication_0_history_loss.png",f"/content/Alabama/Tensorflow/Batch_Size_6/40_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fold_{x}_replication_0_history_loss.png")

  print("\n\n")
# Out:
# Fold 1
#
#
# Pytorch:
# Tensorflow:
# Fold 2
#
#
# Pytorch:
# Tensorflow:
# Fold 3
#
#
# Pytorch:
# Tensorflow:
# Fold 4
#
#
# Pytorch:
# Tensorflow:
# Fold 5
#
#
# Pytorch:
# Tensorflow:

# %% [markdown]
# #Comparação Acurácia: Epochs 20 e 40, batch_size 6

# %%
print("\n\n")
for x in range(num_linhas):
  print(f"Fold {x+1}")
  print("\n")
  print("Pytorch:")
  plotar_imagens(f"/content/Alabama/Pytorch/Batch_Size_6/Epochs_20/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fold_{x}_replication_0_history_accuracy.png",f"/content/Alabama/Pytorch/Batch_Size_6/Epochs_40/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fold_{x}_replication_0_history_accuracy.png")
  print("Tensorflow:")
  plotar_imagens(f"/content/Alabama/Tensorflow/Batch_Size_6/20_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fold_{x}_replication_0_history_accuracy.png",f"/content/Alabama/Tensorflow/Batch_Size_6/40_Epochs/Alabama/output/poi_categorization_job/base/not_directed/gowalla/US/AL/7_categories/5_folds/1_replications/fold_{x}_replication_0_history_accuracy.png")

  print("\n\n")
# Out:
# Fold 1
#
#
# Pytorch:
# Tensorflow:
# Fold 2
#
#
# Pytorch:
# Tensorflow:
# Fold 3
#
#
# Pytorch:
# Tensorflow:
# Fold 4
#
#
# Pytorch:
# Tensorflow:
# Fold 5
#
#
# Pytorch:
# Tensorflow:

# %% [markdown]
# <h2> <b> Antes de iniciar o programa favor fazer o upload do arquivo "Metricas_CSV.zip". </b> </h2>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# !unzip Metricas_CSV.zip
# Out:
# Archive:  Metricas_CSV.zip
# replace Metricas_CSV/pytorch/fscore.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
def fazer_histograma(df1,df2,descricao1,descricao2):
  plt.hist(df1, alpha=0.5, label=descricao1)
  plt.hist(df2, alpha=0.5, label=descricao2)
  plt.xlabel('Valores')
  plt.ylabel('Frequência')
  plt.title('Histograma dos Dados')
  plt.legend(loc='upper right')
  plt.show()

def comparar_graficamente(dict1, dict2, descricao1, descricao2, tipo):
    categorias = list(dict1.keys())
    valores_dict1 = list(dict1.values())
    valores_dict2 = list(dict2.values())

    posicoes = np.arange(len(categorias))

    largura_barra = 0.35

    plt.figure(figsize=(10, 6))
    plt.bar(posicoes - largura_barra/2, valores_dict1, width=largura_barra, label=descricao1, color='blue')
    plt.bar(posicoes + largura_barra/2, valores_dict2, width=largura_barra, label=descricao2, color='orange')

    plt.xlabel('Categorias')
    plt.ylabel('Valores')
    plt.title('Comparação métrica média ' + tipo + ':')
    plt.xticks(posicoes, categorias)
    plt.legend()

    plt.tight_layout()
    plt.show()

# %%
def calcular_medias_por_coluna(nome_arquivo):
    df = pd.read_csv(nome_arquivo)
    df = df.astype(float)

    medias = df.mean().tolist()

    rotulos_colunas = df.columns.tolist()

    medias_com_rotulos = dict(zip(rotulos_colunas, medias))

    return medias_com_rotulos

# %%
def calcular_medias_por_coluna(nome_arquivo):
    df = pd.read_csv(nome_arquivo)
    df = df.astype(float)

    medias = df.mean().tolist()

    rotulos_colunas = df.columns.tolist()

    medias_com_rotulos = dict(zip(rotulos_colunas, medias))

    return medias_com_rotulos

# %%
def retornar_linha_valor(nome_arquivo, linha):
    df = pd.read_csv(nome_arquivo)
    df = df.astype(float)

    valores_linha = df.iloc[linha].to_dict()

    return valores_linha

# %% [markdown]
# <h1> Precisão </h1>

# %%
precisao_pytorch_media = calcular_medias_por_coluna("Metricas_CSV/pytorch/precision.csv")
precisao_tensorflow_media = calcular_medias_por_coluna("Metricas_CSV/tensorflow/precision.csv")
comparar_graficamente(precisao_pytorch_media, precisao_tensorflow_media,"pytorch","tensorflow","precision")

# %% [markdown]
# <h1> Recall </h1>

# %%
precisao_pytorch_media = calcular_medias_por_coluna("Metricas_CSV/pytorch/recall.csv")
precisao_tensorflow_media = calcular_medias_por_coluna("Metricas_CSV/tensorflow/recall.csv")
comparar_graficamente(precisao_pytorch_media, precisao_tensorflow_media,"pytorch","tensorflow","recall")

# %% [markdown]
# <h1> Fscore </h1>

# %%
precisao_pytorch_media = calcular_medias_por_coluna("Metricas_CSV/pytorch/fscore.csv")
precisao_tensorflow_media = calcular_medias_por_coluna("Metricas_CSV/tensorflow/fscore.csv")
comparar_graficamente(precisao_pytorch_media, precisao_tensorflow_media,"pytorch","tensorflow","fscore")

# %% [markdown]
# #Por linha

# %% [markdown]
# <h1> Precisão por linha </h1>

# %%
num_linhas = pd.read_csv("Metricas_CSV/pytorch/precision.csv").shape[0]
for x in range(num_linhas):
  print(f"Precisao linha {x+1}:")
  precisao_pytorch_linha_x = retornar_linha_valor("Metricas_CSV/pytorch/precision.csv",x)
  precisao_tensorflow_linha_x= retornar_linha_valor("Metricas_CSV/tensorflow/precision.csv",x)
  comparar_graficamente(precisao_pytorch_linha_x, precisao_tensorflow_linha_x,"pytorch","tensorflow","precision")
# Out:
# Precisao linha 1:
# Precisao linha 2:
# Precisao linha 3:
# Precisao linha 4:
# Precisao linha 5:

# %% [markdown]
# <h1> Fscore por linha </h1>

# %%
num_linhas = pd.read_csv("Metricas_CSV/pytorch/fscore.csv").shape[0]
for x in range(num_linhas):
  print(f"Fscore linha {x+1}:")
  precisao_pytorch_linha_x = retornar_linha_valor("Metricas_CSV/pytorch/fscore.csv",x)
  precisao_tensorflow_linha_x= retornar_linha_valor("Metricas_CSV/tensorflow/fscore.csv",x)
  comparar_graficamente(precisao_pytorch_linha_x, precisao_tensorflow_linha_x,"pytorch","tensorflow","fscore")
# Out:
# Fscore linha 1:
# Fscore linha 2:
# Fscore linha 3:
# Fscore linha 4:
# Fscore linha 5:

# %% [markdown]
# <h1> Recall por linha </h1>

# %%
num_linhas = pd.read_csv("Metricas_CSV/pytorch/recall.csv").shape[0]
for x in range(num_linhas):
  print(f"Recall linha {x+1}:")
  precisao_pytorch_linha_x = retornar_linha_valor("Metricas_CSV/pytorch/recall.csv",x)
  precisao_tensorflow_linha_x= retornar_linha_valor("Metricas_CSV/tensorflow/recall.csv",x)
  comparar_graficamente(precisao_pytorch_linha_x, precisao_tensorflow_linha_x,"pytorch","tensorflow","recall")
# Out:
# Recall linha 1:
# Recall linha 2:
# Recall linha 3:
# Recall linha 4:
# Recall linha 5:
